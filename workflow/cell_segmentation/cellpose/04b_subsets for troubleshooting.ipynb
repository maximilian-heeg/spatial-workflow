# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("cellpose_segmentation/transcripts.csv")

# %%
data
# Out:
#           Unnamed: 0.1  Unnamed: 0  barcode_id   global_x     global_y  \
# 0                    0      329140          96  3822.6140   134.603240
# 1                    1      425522         128  3865.5085    89.455734
# 2                    2      810570         241  3972.9065   163.452200
# 3                    3     1294999         381  3968.8958    33.911680
# 4                    4     1844539         536  3814.5425   132.516770
# ...                ...         ...         ...        ...          ...
# 16296383      16296383      891678         260  2750.3667  7003.081500
# 16296384      16296384     1096165         316  2643.0085  6867.693000
# 16296385      16296385     1337621         386  2659.0680  6997.968000
# 16296386      16296386     1622514         477  2635.3728  6870.979500
# 16296387      16296387     1622590         477  2810.0360  6958.539600
#
#           global_z           x           y  fov      gene       transcript_id  \
# ...

# %%
data_subset = data[
    (data.global_x > 2200) &  (data.global_x < 3800) &
    (data.global_y > 2200) &  (data.global_y < 3800)
]

# %%
data_subset
# Out:
#          Unnamed: 0.1  Unnamed: 0  barcode_id   global_x   global_y  global_z  \
# 4332881       4332881        1231           1  3627.1620  2200.0050       0.0
# 4332889       4332889        1692           1  3612.0935  2206.9036       1.0
# 4332890       4332890        1695           1  3622.2990  2208.7095       1.0
# 4332891       4332891        1696           1  3621.5176  2208.9019       1.0
# 4332917       4332917        2630           1  3711.0870  2200.0193       3.0
# ...               ...         ...         ...        ...        ...       ...
# 9025483       9025483     1762436         487  2208.8777  3758.8025       0.0
# 9025484       9025484     1762440         487  2208.6510  3759.7375       0.0
# 9025814       9025814     1764102         487  2208.4558  3757.2253       1.0
# 9026176       9026176     1765882         487  2208.8723  3758.6426       2.0
# 9026177       9026177     1765885         487  2209.2214  3759.6100       2.0
#
# ...

# %%
data_subset.to_csv("cellpose_segmentation/transcripts_subset.csv")
